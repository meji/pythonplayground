# %% [markdown]
# # Aprendizaje supervisado

# %% [markdown]
# En esta sesión veremos como implementar los distintos algoritmos de aprendizaje supervisado que hemos presentado en el fastbook. Para ello, usaremos un par de datasets de kaggle y la librería scikit-learn.

# %% [markdown]
# # Regresión

# %%
import pandas as pd
import numpy as np

rn_state = 42 # random state for reproducibility

# %% [markdown]
# Cargamos un dataset de kaggle ([perth-house-pries](https://www.kaggle.com/datasets/syuzai/perth-house-prices))
#
# dedicado a la predicción de precios de casas en Boston.

# %%
df_houses = pd.read_csv('housing.csv')
df_houses.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160      2003.0     18300  Cockburn Central Station
# 1        351         139      2013.0     26900           Kwinana Station
# 2        719          86      1979.0     22600           Challis Station
# 3        651          59      1953.0     17900           Midland Station
# 4        466         131      1998.0     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# 0              1800  09-2018\r      6164 -32.115900  115.842450
# 1              4900  02-2019\r      6167 -32.193470  115.859554
# 2              1900  06-2015\r      6111 -32.120578  115.993579
# 3              3600  07-2018\r      6056 -31.900547  116.038009
# 4              2000  11-2016\r      6054 -31.885790  115.947780
#
#                     NEAREST_SCH  NEAREST_SCH_DIST  NEAREST_SCH_RANK
# 0   LAKELAND SENIOR HIGH SCHOOL          0.828339               NaN
# 1                ATWELL COLLEGE          5.524324             129.0
# 2  KELMSCOTT SENIOR HIGH SCHOOL          1.649178             113.0
# 3  SWAN VIEW SENIOR HIGH SCHOOL          1.571401               NaN
# 4                 KIARA COLLEGE          1.514922               NaN

# %% [markdown]
# Vemos que el dataset tiene una mezcla de valores numéricos y strings.
#
# Seguramente no todos estos datos nos serán útiles, así que eliminamos los que consideremos de poca utilidad

# %%
df_houses_clean = df_houses.drop(columns=['ADDRESS', 'SUBURB','NEAREST_STN', 'DATE_SOLD', 'NEAREST_SCH', 'NEAREST_SCH_RANK'])
df_houses_clean.head()
# Out:
#     PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  \
# 0  565000         4          2     2.0        600         160      2003.0
# 1  365000         3          2     2.0        351         139      2013.0
# 2  287000         3          1     1.0        719          86      1979.0
# 3  255000         2          1     2.0        651          59      1953.0
# 4  325000         4          1     2.0        466         131      1998.0
#
#    CBD_DIST  NEAREST_STN_DIST  POSTCODE   LATITUDE   LONGITUDE  \
# 0     18300              1800      6164 -32.115900  115.842450
# 1     26900              4900      6167 -32.193470  115.859554
# 2     22600              1900      6111 -32.120578  115.993579
# 3     17900              3600      6056 -31.900547  116.038009
# 4     11200              2000      6054 -31.885790  115.947780
#
#    NEAREST_SCH_DIST
# 0          0.828339
# 1          5.524324
# 2          1.649178
# 3          1.571401
# 4          1.514922

# %% [markdown]
# Ahora comprobamos si hay algún campo con valores nan, y planteamos cómo limpiar estos valores

# %%
for columns in df_houses_clean.columns:
    print(columns, df_houses_clean[columns].isnull().sum()*100/len(df_houses_clean))
# Out:
# PRICE 0.0
# BEDROOMS 0.0
# BATHROOMS 0.0
# GARAGE 7.362728785357737
# LAND_AREA 0.0
# FLOOR_AREA 0.0
# BUILD_YEAR 9.374257190396957
# CBD_DIST 0.0
# NEAREST_STN_DIST 0.0
# POSTCODE 0.0
# LATITUDE 0.0
# LONGITUDE 0.0
# NEAREST_SCH_DIST 0.0

# %% [markdown]
# Podemos suponer que los pisos sin garage puedan ser nan, por lo que lo comprobamos.

# %%
df_houses_clean['GARAGE'].value_counts(dropna=False)
# Out:
# GARAGE
# 2.0     20724
# 1.0      5290
# NaN      2478
# 3.0      2042
# 4.0      1949
# 6.0       466
# 5.0       362
# 8.0       129
# 7.0        97
# 12.0       30
# 10.0       26
# 9.0        17
# 14.0       13
# 13.0        8
# 11.0        7
# 16.0        4
# 18.0        3
# 20.0        3
# 32.0        1
# 17.0        1
# 21.0        1
# 99.0        1
# 26.0        1
# 22.0        1
# 50.0        1
# 31.0        1
# Name: count, dtype: int64

# %% [markdown]
# Vemos datos extraños (¿casas con 99 garajes?) Esto nos puede indicar que este dataset no es muy fiable, pero para el uso que queremos darle nos valdrá.
#
# Por otro lado, podemos confirmar que los valores nan de garage son los que no tienen garage. Por lo que podemos convertir a 0.

# %%
df_houses_clean['GARAGE'] = df_houses_clean['GARAGE'].fillna(0)
df_houses_clean = df_houses_clean.dropna()

# %% [markdown]
# Con los datos limpios, podemos dividirlos en train y test (Validación).

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_houses_clean.drop(columns=['PRICE']),
    df_houses_clean['PRICE'],
    test_size=0.2,
    random_state=rn_state)

# %% [markdown]
# ## Regresión lineal

# %% [markdown]
# Con nuestros datos limpios, podemos empezar a modelar.

# %% [markdown]
# Para utilizar modelos clásicos, usaremos la librería scikit-learn. Esta librería tiene una interfaz muy sencilla, y es muy fácil de usar.
# https://scikit-learn.org/stable/
#
# Es comúnmente usada y veremos que el uso de sus modelos es bastante estandarizado.
# Por lo general necesitaremos:
# - Cargar el modelo
# - Hacer fit() con los datos de entrenamiento
# - Comprobar el score con los datos de test
# - Utilizarlo con predict()

# %%
from sklearn import linear_model

regressor = linear_model.LinearRegression()
regressor = regressor.fit(X_train, y_train)

# %% [markdown]
# Con esto hemos entrenado un modelo, ahora podríamos simplemente utilizarlo para predecir el precio de una casa.

# %%
# entrada: BEDROOMS, BATHROOMS, GARAGE, LAND_AREA, FLOOR_AREA, BUILD_YEAR, CBD_DIST, NEAREST_STN_DIST, POSTCODE, LATITUDE, LONGITUDE, NEAREST_SCH_DIST
example_data = [[4, 2, 2.0,	600, 160, 2003.0, 18300, 1800, 6164, -32.115900, 115.842450, 0.828339]]
prediction = regressor.predict(example_data)
print(prediction)
# Out:
# [539539.50443631]
# /Users/jesusmartinmejias/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Podemos incluso analizar los componenetes del modelo de regresión lineal, que si recordamos, es una combinación lineal de los datos de entrada.
# Los dos componenetes principales son el interceptor y los pesos

# %%
interceptor = regressor.intercept_
weights = regressor.coef_
print(interceptor)
print(weights)
# Out:
# 115765308.97234541
# [-1.30193490e+04  1.02576192e+05  1.08292802e+04  1.45423508e+00
#   2.37943526e+03 -3.92924316e+03 -1.44208707e+01  1.64252246e+01
#  -7.75242959e+02 -3.81428679e+05 -9.94120245e+05  1.51174948e+04]

# %% [markdown]
# Pero como evaluamos lo bien o mal que lo hace el modelo? Podemos usar el score, pero qué significa?
# El score en regresión lineal es el R2, que nos indica la proporción de la varianza de la variable dependiente que es predecible a partir de las variables independientes.

# %%
score = regressor.score(X_train, y_train)
print('R^2 del modelo: %.2f'% score)
# Out:
# R^2 del modelo: 0.58

# %% [markdown]
# Desde el punto de vista estadístico R2 es la métrica que más claramente nos muestra la relación entre entrada y salida, pero no nos indica tanto el error.
#
# Para saber el error absoluto medio (MAE), que nos indica la media de los errores absolutos o el error podemos usar la del error cuadrático medio (MSE), que nos indica la media de los errores al cuadrado.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error 

y_predicted = regressor.predict(X_train)
print('Mean absolute error: %.2f' % mean_absolute_error(y_train, y_predicted))
print('Mean squared error: %.2f' % mean_squared_error(y_train, y_predicted))
# Out:
# Mean absolute error: 157208.94
# Mean squared error: 53811827908.22

# %% [markdown]
# El error medio absoluto es alto, pero razonable.
#
# Pero ese squared error es enorme!
#
# ¿A qué se debe? MSE no está en dolares, sino el dolares cuadrados. Por ello es común usar la raiz de este error, ya que representa el error en la misma unidad que la variable dependiente.

# %%
print('Mean absolute error: %.2f' % mean_absolute_error(y_train, y_predicted))
print('Root Mean squared error: %.2f' % np.sqrt(mean_squared_error(y_train, y_predicted)))
# Out:
# Mean absolute error: 157208.94
# Root Mean squared error: 231973.77

# %% [markdown]
# Si los errores son correctos, deberíamos poder ver una varianza entre lo predicho y lo real de alrededor de 100.000 - 200.000 dolares.

# %%
for predicted, actual in zip(y_predicted[:10], y_train[:10]):
    print(f'predicted: {predicted:.2f}, actual: {actual:.2f}, difference: {abs(predicted - actual):.2f}')
# Out:
# predicted: 465476.68, actual: 355000.00, difference: 110476.68
# predicted: 641318.04, actual: 580000.00, difference: 61318.04
# predicted: 543562.10, actual: 585000.00, difference: 41437.90
# predicted: 720334.46, actual: 584000.00, difference: 136334.46
# predicted: 454564.05, actual: 385000.00, difference: 69564.05
# predicted: 340732.81, actual: 410000.00, difference: 69267.19
# predicted: 752747.19, actual: 569400.00, difference: 183347.19
# predicted: 434760.19, actual: 255000.00, difference: 179760.19
# predicted: 583663.82, actual: 530000.00, difference: 53663.82
# predicted: 1058832.84, actual: 1100000.00, difference: 41167.16

# %% [markdown]
# Los errores parecen corresponderse a cifras con sentido, pero puede que haya varias cifras con errores muy grandes

# %%
counter = 0
for predicted, actual in zip(y_predicted, y_train):
    if np.absolute(actual - predicted) > 1_000_000:
        counter += 1
        print(f'big error predicted: {predicted:.2f}, actual: {actual:.2f}')
        if counter > 10:
            break
# Out:
# big error predicted: 1114309.19, actual: 2410000.00
# big error predicted: 1333835.15, actual: 2437000.00
# big error predicted: 1286202.06, actual: 85000.00
# big error predicted: 1343774.06, actual: 2400000.00
# big error predicted: 1164967.77, actual: 2400000.00
# big error predicted: 179157.40, actual: 1440000.00
# big error predicted: -411193.30, actual: 658500.00
# big error predicted: 827452.59, actual: 1920000.00
# big error predicted: 902728.99, actual: 2425000.00
# big error predicted: 1217302.47, actual: 190000.00
# big error predicted: 1249917.70, actual: 2300000.00

# %% [markdown]
# Los errores más grandes se acercan a lo estimado por el RMSE. Por lo que es un error que nos indicará mejor por cuanto se equivoca el modelo en el peor de los casos.
#
# Aún podemos hacer algo mejor e intentar estimar en qué casos el modelo es más propenso a equivocarse.

# %%
from matplotlib import pyplot as plt
plt.scatter(y_train, y_predicted)
plt.show()

# %% [markdown]
# Aquí podemos ver que a precios bajos, nuestro modelo puede dar valores negativos, y que hay un ligero incremento de precisión a medida que aumenta el precio (Aunque muy ligero). Por lo general las métricas se van a mantener a lo largo de todo el rango de precios.

# %% [markdown]
# Por ahora hemos evaluado los resultados de entrenamiento, pero realmente lo que nos interesa es el resultado de test. Estos son datos que el modelo desconoce, y por lo tanto, nos darán una mejor idea de cómo se comportará el modelo en el mundo real.

# %%
y_predicted_train = regressor.predict(X_train)
print('Train Mean absolute error: %.2f' % mean_absolute_error(y_train, y_predicted_train))
print('Train Mean squared error: %.2f' % np.sqrt(mean_squared_error(y_train, y_predicted_train)))

y_predicted = regressor.predict(X_test)
print('Test Mean absolute error: %.2f' % mean_absolute_error(y_test, y_predicted))
print('Test Mean squared error: %.2f' % np.sqrt(mean_squared_error(y_test, y_predicted)))
# Out:
# Train Mean absolute error: 157208.94
# Train Mean squared error: 231973.77
# Test Mean absolute error: 153040.91
# Test Mean squared error: 226091.98

# %% [markdown]
# Vemos que los resultados son similares, por lo que podemos estar seguros de que el modelo no está sobreajustado.

# %%
plt.scatter(y_test, y_predicted)
plt.show()

# %% [markdown]
# Incluso en la gráfica vemos un comportamiento similar

# %% [markdown]
# ## Modelo LASSO

# %% [markdown]
# En regresión lineal nos hemos parado más en cómo evaluar un modelo de regresión, que en el modelo en sí. Ahora vamos a ver un modelo de regresión lineal regularizado, LASSO.
#
# Vamos a ver que los pasos son similares sino idénticos a los de regresión lineal.

# %% [markdown]
# Cargamos el modelo y lo entrenamos

# %%
lasso = linear_model.Lasso(alpha=0.1)
lasso = lasso.fit(X_train, y_train)

# %% [markdown]
# Este modelo ya podemos usarlo para hacer nuevas predicciones

# %%
# entrada: BEDROOMS, BATHROOMS, GARAGE, LAND_AREA, FLOOR_AREA, BUILD_YEAR, CBD_DIST, NEAREST_STN_DIST, POSTCODE, LATITUDE, LONGITUDE, NEAREST_SCH_DIST
example_data = [[4, 2, 2.0,	600, 160, 2003.0, 18300, 1800, 6164, -32.115900, 115.842450, 0.828339]]
prediction = lasso.predict(example_data)
print(prediction)
# Out:
# [539539.29583681]
# /Users/jesusmartinmejias/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Podemos calcular sus métricas de la misma forma

# %%
y_predicted = lasso.predict(X_train)
print('Mean absolute error: %.2f' % mean_absolute_error(y_train, y_predicted))
print('Root Mean squared error: %.2f' % np.sqrt(mean_squared_error(y_train, y_predicted)))
# Out:
# Mean absolute error: 157208.82
# Root Mean squared error: 231973.77

# %% [markdown]
# Y podemos visualizarlo igual

# %%
plt.scatter(y_train, y_predicted)
plt.show()

# %% [markdown]
# Igual en test

# %%
y_predicted = lasso.predict(X_test)
print('Mean absolute error: %.2f' % mean_absolute_error(y_test, y_predicted))
print('Root Mean squared error: %.2f' % np.sqrt(mean_squared_error(y_test, y_predicted)))
# Out:
# Mean absolute error: 153040.77
# Root Mean squared error: 226091.93

# %%
plt.scatter(y_test, y_predicted)
plt.show()

# %% [markdown]
# Con esto, podemos ver cómo evaluar y comparar modelos de regresión. Podemos expandir esta idea a cualquier modelo de regresión e incluso podemos usar sus librerías para modificarlos.

# %% [markdown]
# # Clasificación

# %% [markdown]
# Para clasificación empezaremos con un dataset sencillo, [iris](https://www.kaggle.com/datasets/uciml/iris)
#
# Un dataset dedicado a la clasificación de flores de iris. Según características como el tamaño de los pétalos, el tamaño de los sépalos, etc.

# %%
df_iris = pd.read_csv('IRIS.csv')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_iris['species'].value_counts(dropna=False)
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Este dataset ya está limpio, por lo que tan sólo necesitamos dividirlo en train y test.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_iris.drop(columns=['species']), 
    df_iris['species'], 
    test_size=0.2, 
    random_state=rn_state)

# %% [markdown]
# ## Árboles de decisión

# %% [markdown]
# Empezaremos estudiando los árboles de decisión, que son un modelo muy sencillo de entender y que nos permitirá ver cómo se comportan los modelos de clasificación.
# Una vez más usaremos la librería de scikit-learn. Y veremos que el uso de los modelos es igual.

# %%
from sklearn import tree 

DT = tree.DecisionTreeClassifier(random_state=rn_state)
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# Y podemos usarlo de la misma forma

# %%
# entrada: sepal_length, sepal_width, petal_length, petal_width
example_data = [[5.1, 3.5, 1.4, 0.2]]
prediction = DT.predict(example_data)
print(prediction)
# Out:
# ['Iris-setosa']
# /Users/jesusmartinmejias/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Vemos el score del modelo

# %%
print('Accuracy en entrenamiento %.2f'%DT.score(X_train, y_train))
print('Accuracy en test %.2f'%DT.score(X_test, y_test))
# Out:
# Accuracy en entrenamiento 1.00
# Accuracy en test 1.00

# %% [markdown]
# Tenemos un accuracy perfecto tanto en entrenamiento como en test, por lo que hasta donde sabemos nuestro modelo no comete fallos (En realidad podemos determinar que no tenemos datos suficientes como para sabe ren qué puntos nuestro modelo falla)

# %% [markdown]
# Visualizamos el arbol de decisión

# %%
tree.plot_tree(DT,
               feature_names=X_train.columns.tolist(),
               class_names=df_iris['species'].unique().tolist(),
               filled=True,
               rounded=True)
# Out:
# [Text(0.3076923076923077, 0.9285714285714286, 'petal_length <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]\nclass = Iris-versicolor'),
#  Text(0.23076923076923078, 0.7857142857142857, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = Iris-setosa'),
#  Text(0.38461538461538464, 0.7857142857142857, 'petal_length <= 4.75\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]\nclass = Iris-versicolor'),
#  Text(0.15384615384615385, 0.6428571428571429, 'petal_width <= 1.65\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]\nclass = Iris-versicolor'),
#  Text(0.07692307692307693, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = Iris-versicolor'),
#  Text(0.23076923076923078, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
#  Text(0.6153846153846154, 0.6428571428571429, 'petal_width <= 1.75\ngini = 0.206\nsamples = 43\nvalue = [0, 5, 38]\nclass = Iris-virginica'),
#  Text(0.38461538461538464, 0.5, 'petal_length <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = Iris-versicolor'),
#  Text(0.3076923076923077, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Iris-versicolor'),
#  Text(0.46153846153846156, 0.35714285714285715, 'petal_width <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = Iris-virginica'),
#  Text(0.38461538461538464, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Iris-virginica'),
#  Text(0.5384615384615384, 0.21428571428571427, 'petal_length <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = Iris-versicolor'),
#  Text(0.46153846153846156, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Iris-versicolor'),
#  Text(0.6153846153846154, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
#  Text(0.8461538461538461, 0.5, 'petal_length <= 4.85\ngini = 0.056\nsamples = 35\nvalue = [0, 1, 34]\nclass = Iris-virginica'),
#  Text(0.7692307692307693, 0.35714285714285715, 'sepal_width <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Iris-virginica'),
#  Text(0.6923076923076923, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Iris-virginica'),
#  Text(0.8461538461538461, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-versicolor'),
#  Text(0.9230769230769231, 0.35714285714285715, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 32]\nclass = Iris-virginica')]

# %% [markdown]
# Para ver casos más complejos, veamos otro dataset.
#
# [dataset titanic](https://www.kaggle.com/datasets/heptapod/titanic)
#
# Dedicado a información sobre los pasajeros del titanic, como su edad, sexo, clase, etc. Y si sobrevivieron o no.

# %%
df_titanic = pd.read_excel('Titanic_dataset.xlsx')
df_titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df_titanic['survived'].value_counts(dropna=False)
# Out:
# survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %% [markdown]
# Suponemos que 1 equivale a superviviente y 0 a no superviviente

# %% [markdown]
# Limpiamos los datos que no creemos que sean útiles Y transformamos los datos de tipo string en numéricos

# %%
df_titanic_clean = df_titanic.drop(columns=['name', 'ticket', 'cabin', 'boat', 'body', 'home.dest'])
df_titanic_clean['sex'] = pd.factorize(df_titanic_clean['sex'])[0]
df_titanic_clean['embarked'] = pd.factorize(df_titanic_clean['embarked'])[0]
df_titanic_clean.head()
# Out:
#    pclass  survived  sex      age  sibsp  parch      fare  embarked
# 0       1         1    0  29.0000      0      0  211.3375         0
# 1       1         1    1   0.9167      1      2  151.5500         0
# 2       1         0    0   2.0000      1      2  151.5500         0
# 3       1         0    1  30.0000      1      2  151.5500         0
# 4       1         0    0  25.0000      1      2  151.5500         0

# %%
for column in df_titanic_clean.columns:
    print(column, df_titanic_clean[column].isnull().sum()*100/len(df_titanic_clean))
# Out:
# pclass 0.0
# survived 0.0
# sex 0.0
# age 20.091673032849503
# sibsp 0.0
# parch 0.0
# fare 0.07639419404125286
# embarked 0.0

# %%
df_titanic_clean['age'] = df_titanic_clean['age'].fillna(df_titanic_clean['age'].mean())
df_titanic_clean['fare'] = df_titanic_clean['fare'].fillna(df_titanic_clean['fare'].mean())

# %% [markdown]
# Dividimos los datos en entrenamiento y test

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_titanic_clean.drop(columns=['survived']),
    df_titanic_clean['survived'], 
    test_size=0.2, 
    random_state=rn_state)

# %%
DT = tree.DecisionTreeClassifier(random_state=rn_state)
DT = DT.fit(X_train, y_train)
print('train accuracy: %.2f' % DT.score(X_train, y_train))
print('test accuracy: %.2f' % DT.score(X_test, y_test))
# Out:
# train accuracy: 0.97
# test accuracy: 0.79

# %% [markdown]
# Ahora sí vemos que nuestro accuracy no es perfecto, pero no sabemos en qué fallamos. Para ello podemos usar las otras métricas que hemos visto

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_predicted = DT.predict(X_test)
print('precision: %.2f' % precision_score(y_test, y_predicted))
print('recall: %.2f' % recall_score(y_test, y_predicted))
print('f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# precision: 0.81
# recall: 0.71
# f1: 0.76

# %% [markdown]
# Vemos una precisión alta pero un recall bajo
# Lo que nos indica que no siempre detectamos a los supervivientes, pero cuando lo hacemos, es muy probable que sea un superviviente.

# %% [markdown]
# Otra forma de visualizarlo es con una matriz de confusión

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_predicted, labels=DT.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DT.classes_)
disp.plot()
plt.show()

# %% [markdown]
# De aquí vemos que cuando hay superviviente (True label 1) hay casi un 50% posibilidades de que lo detectemos.
# Pero cuando el modelo da una respuesta, tenemos una posibilidad grande de haber acertado.
#
# Predicted label 0: 72%
#
# Predicted label 1: 82%
#
# Esto se debe a la desproporción superviviente/no superviviente

# %%
tree.plot_tree(DT,
               feature_names=X_train.columns.tolist(),
               class_names=['Not survived', 'Survived'],
               filled=True,
               rounded=True)
# Out:
# [Text(0.3231313694788757, 0.9772727272727273, 'sex <= 0.5\ngini = 0.463\nsamples = 1047\nvalue = [665, 382]\nclass = Not survived'),
#  Text(0.1618802374301676, 0.9318181818181818, 'pclass <= 2.5\ngini = 0.409\nsamples = 370\nvalue = [106, 264]\nclass = Survived'),
#  Text(0.06983240223463687, 0.8863636363636364, 'fare <= 32.09\ngini = 0.124\nsamples = 195\nvalue = [13, 182]\nclass = Survived'),
#  Text(0.05865921787709497, 0.8409090909090909, 'fare <= 31.34\ngini = 0.223\nsamples = 86\nvalue = [11, 75]\nclass = Survived'),
#  Text(0.05307262569832402, 0.7954545454545454, 'age <= 59.0\ngini = 0.208\nsamples = 85\nvalue = [10, 75]\nclass = Survived'),
#  Text(0.04189944134078212, 0.75, 'parch <= 1.5\ngini = 0.193\nsamples = 83\nvalue = [9, 74]\nclass = Survived'),
#  Text(0.036312849162011177, 0.7045454545454546, 'fare <= 12.675\ngini = 0.216\nsamples = 73\nvalue = [9, 64]\nclass = Survived'),
#  Text(0.030726256983240222, 0.6590909090909091, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Survived'),
#  Text(0.04189944134078212, 0.6590909090909091, 'fare <= 13.25\ngini = 0.236\nsamples = 66\nvalue = [9, 57]\nclass = Survived'),
#  Text(0.0223463687150838, 0.6136363636363636, 'age <= 26.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.0111731843575419, 0.5681818181818182, 'sibsp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.00558659217877095, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.01675977653631285, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.0335195530726257, 0.5681818181818182, 'age <= 37.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.027932960893854747, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.03910614525139665, 0.5227272727272727, 'age <= 39.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.0335195530726257, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.0446927374301676, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.061452513966480445, 0.6136363636363636, 'age <= 21.5\ngini = 0.191\nsamples = 56\nvalue = [6, 50]\nclass = Survived'),
#  Text(0.055865921787709494, 0.5681818181818182, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.0670391061452514, 0.5681818181818182, 'age <= 22.5\ngini = 0.24\nsamples = 43\nvalue = [6, 37]\nclass = Survived'),
#  Text(0.061452513966480445, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.07262569832402235, 0.5227272727272727, 'sibsp <= 0.5\ngini = 0.21\nsamples = 42\nvalue = [5, 37]\nclass = Survived'),
#  Text(0.055865921787709494, 0.4772727272727273, 'fare <= 28.217\ngini = 0.091\nsamples = 21\nvalue = [1, 20]\nclass = Survived'),
#  Text(0.05027932960893855, 0.4318181818181818, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = Survived'),
#  Text(0.061452513966480445, 0.4318181818181818, 'fare <= 29.856\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.055865921787709494, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.0670391061452514, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.0893854748603352, 0.4772727272727273, 'fare <= 26.125\ngini = 0.308\nsamples = 21\nvalue = [4, 17]\nclass = Survived'),
#  Text(0.08379888268156424, 0.4318181818181818, 'parch <= 0.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]\nclass = Survived'),
#  Text(0.0782122905027933, 0.38636363636363635, 'age <= 43.0\ngini = 0.32\nsamples = 15\nvalue = [3, 12]\nclass = Survived'),
#  Text(0.0670391061452514, 0.3409090909090909, 'age <= 29.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Survived'),
#  Text(0.061452513966480445, 0.29545454545454547, 'fare <= 22.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = Survived'),
#  Text(0.05027932960893855, 0.25, 'embarked <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.0446927374301676, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.055865921787709494, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.07262569832402235, 0.25, 'age <= 28.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.0670391061452514, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.0782122905027933, 0.20454545454545456, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.07262569832402235, 0.29545454545454547, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.0893854748603352, 0.3409090909090909, 'age <= 49.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.08379888268156424, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.09497206703910614, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.0893854748603352, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.09497206703910614, 0.4318181818181818, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.04748603351955307, 0.7045454545454546, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.06424581005586592, 0.75, 'age <= 62.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.05865921787709497, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.06983240223463687, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.06424581005586592, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.08100558659217877, 0.8409090909090909, 'age <= 3.0\ngini = 0.036\nsamples = 109\nvalue = [2, 107]\nclass = Survived'),
#  Text(0.07541899441340782, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.08659217877094973, 0.7954545454545454, 'parch <= 1.5\ngini = 0.018\nsamples = 108\nvalue = [1, 107]\nclass = Survived'),
#  Text(0.08100558659217877, 0.75, 'gini = 0.0\nsamples = 91\nvalue = [0, 91]\nclass = Survived'),
#  Text(0.09217877094972067, 0.75, 'fare <= 135.775\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = Survived'),
#  Text(0.08659217877094973, 0.7045454545454546, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.09776536312849161, 0.7045454545454546, 'fare <= 206.963\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = Survived'),
#  Text(0.09217877094972067, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.10335195530726257, 0.6590909090909091, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.25392807262569833, 0.8863636363636364, 'fare <= 23.35\ngini = 0.498\nsamples = 175\nvalue = [93, 82]\nclass = Not survived'),
#  Text(0.20897346368715083, 0.8409090909090909, 'fare <= 7.267\ngini = 0.495\nsamples = 144\nvalue = [65, 79]\nclass = Survived'),
#  Text(0.2033868715083799, 0.7954545454545454, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Survived'),
#  Text(0.21456005586592178, 0.7954545454545454, 'fare <= 14.873\ngini = 0.499\nsamples = 136\nvalue = [65, 71]\nclass = Survived'),
#  Text(0.16096368715083798, 0.75, 'fare <= 14.254\ngini = 0.495\nsamples = 96\nvalue = [53, 43]\nclass = Not survived'),
#  Text(0.1361731843575419, 0.7045454545454546, 'age <= 19.5\ngini = 0.5\nsamples = 85\nvalue = [43, 42]\nclass = Not survived'),
#  Text(0.11452513966480447, 0.6590909090909091, 'fare <= 7.39\ngini = 0.463\nsamples = 22\nvalue = [8, 14]\nclass = Survived'),
#  Text(0.10893854748603352, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.12011173184357542, 0.6136363636363636, 'age <= 3.5\ngini = 0.444\nsamples = 21\nvalue = [7, 14]\nclass = Survived'),
#  Text(0.10335195530726257, 0.5681818181818182, 'fare <= 10.798\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.09776536312849161, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.10893854748603352, 0.5227272727272727, 'fare <= 11.658\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not survived'),
#  Text(0.10335195530726257, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.11452513966480447, 0.4772727272727273, 'sibsp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.10893854748603352, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.12011173184357542, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.13687150837988826, 0.5681818181818182, 'fare <= 7.902\ngini = 0.375\nsamples = 16\nvalue = [4, 12]\nclass = Survived'),
#  Text(0.13128491620111732, 0.5227272727272727, 'age <= 15.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = Survived'),
#  Text(0.12569832402234637, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.13687150837988826, 0.4772727272727273, 'age <= 16.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Survived'),
#  Text(0.13128491620111732, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.1424581005586592, 0.4318181818181818, 'age <= 18.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.13687150837988826, 0.38636363636363635, 'embarked <= 1.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.13128491620111732, 0.3409090909090909, 'fare <= 7.635\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.12569832402234637, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.13687150837988826, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.1424581005586592, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.14804469273743018, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.1424581005586592, 0.5227272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Survived'),
#  Text(0.15782122905027932, 0.6590909090909091, 'age <= 21.5\ngini = 0.494\nsamples = 63\nvalue = [35, 28]\nclass = Not survived'),
#  Text(0.15223463687150837, 0.6136363636363636, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not survived'),
#  Text(0.1634078212290503, 0.6136363636363636, 'fare <= 7.675\ngini = 0.5\nsamples = 57\nvalue = [29, 28]\nclass = Not survived'),
#  Text(0.15782122905027932, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.16899441340782123, 0.5681818181818182, 'fare <= 7.744\ngini = 0.499\nsamples = 54\nvalue = [26, 28]\nclass = Survived'),
#  Text(0.1634078212290503, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.17458100558659218, 0.5227272727272727, 'age <= 23.5\ngini = 0.498\nsamples = 49\nvalue = [26, 23]\nclass = Not survived'),
#  Text(0.15921787709497207, 0.4772727272727273, 'fare <= 8.356\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Survived'),
#  Text(0.15363128491620112, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.164804469273743, 0.4318181818181818, 'fare <= 8.812\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.15921787709497207, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.17039106145251395, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.18994413407821228, 0.4772727272727273, 'age <= 25.5\ngini = 0.49\nsamples = 42\nvalue = [24, 18]\nclass = Not survived'),
#  Text(0.18435754189944134, 0.4318181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.19553072625698323, 0.4318181818181818, 'fare <= 10.798\ngini = 0.499\nsamples = 38\nvalue = [20, 18]\nclass = Not survived'),
#  Text(0.18156424581005587, 0.38636363636363635, 'age <= 29.941\ngini = 0.493\nsamples = 34\nvalue = [19, 15]\nclass = Not survived'),
#  Text(0.17039106145251395, 0.3409090909090909, 'fare <= 8.081\ngini = 0.499\nsamples = 27\nvalue = [13, 14]\nclass = Survived'),
#  Text(0.164804469273743, 0.29545454545454547, 'age <= 28.941\ngini = 0.486\nsamples = 24\nvalue = [10, 14]\nclass = Survived'),
#  Text(0.14804469273743018, 0.25, 'fare <= 7.91\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.1424581005586592, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.15363128491620112, 0.20454545454545456, 'sibsp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.14804469273743018, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.15921787709497207, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.18156424581005587, 0.25, 'parch <= 1.0\ngini = 0.444\nsamples = 18\nvalue = [6, 12]\nclass = Survived'),
#  Text(0.17597765363128492, 0.20454545454545456, 'embarked <= 1.0\ngini = 0.415\nsamples = 17\nvalue = [5, 12]\nclass = Survived'),
#  Text(0.17039106145251395, 0.1590909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.18156424581005587, 0.1590909090909091, 'fare <= 7.79\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Survived'),
#  Text(0.17597765363128492, 0.11363636363636363, 'gini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.1871508379888268, 0.11363636363636363, 'fare <= 7.854\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Survived'),
#  Text(0.18156424581005587, 0.06818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.19273743016759776, 0.06818181818181818, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.1871508379888268, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.17597765363128492, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.19273743016759776, 0.3409090909090909, 'age <= 54.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not survived'),
#  Text(0.1871508379888268, 0.29545454545454547, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not survived'),
#  Text(0.19832402234636873, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.20949720670391062, 0.38636363636363635, 'age <= 26.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.20391061452513967, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.21508379888268156, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.1857541899441341, 0.7045454545454546, 'age <= 16.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Not survived'),
#  Text(0.18016759776536312, 0.6590909090909091, 'age <= 14.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.17458100558659218, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.1857541899441341, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.19134078212290503, 0.6590909090909091, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not survived'),
#  Text(0.2681564245810056, 0.75, 'age <= 1.5\ngini = 0.42\nsamples = 40\nvalue = [12, 28]\nclass = Survived'),
#  Text(0.26256983240223464, 0.7045454545454546, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.2737430167597765, 0.7045454545454546, 'age <= 3.5\ngini = 0.451\nsamples = 35\nvalue = [12, 23]\nclass = Survived'),
#  Text(0.2681564245810056, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.27932960893854747, 0.6590909090909091, 'age <= 32.5\ngini = 0.422\nsamples = 33\nvalue = [10, 23]\nclass = Survived'),
#  Text(0.2737430167597765, 0.6136363636363636, 'age <= 29.941\ngini = 0.459\nsamples = 28\nvalue = [10, 18]\nclass = Survived'),
#  Text(0.25977653631284914, 0.5681818181818182, 'embarked <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]\nclass = Survived'),
#  Text(0.24860335195530725, 0.5227272727272727, 'sibsp <= 1.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = Survived'),
#  Text(0.2430167597765363, 0.4772727272727273, 'parch <= 3.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = Survived'),
#  Text(0.23743016759776536, 0.4318181818181818, 'parch <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.23184357541899442, 0.38636363636363635, 'age <= 27.941\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not survived'),
#  Text(0.22625698324022347, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.23743016759776536, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.2430167597765363, 0.38636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Survived'),
#  Text(0.24860335195530725, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.2541899441340782, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.2709497206703911, 0.5227272727272727, 'fare <= 17.379\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = Survived'),
#  Text(0.26536312849162014, 0.4772727272727273, 'age <= 29.441\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = Survived'),
#  Text(0.25977653631284914, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.2709497206703911, 0.4318181818181818, 'fare <= 15.373\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Survived'),
#  Text(0.26536312849162014, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.276536312849162, 0.38636363636363635, 'sibsp <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.2709497206703911, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.28212290502793297, 0.3409090909090909, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.276536312849162, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.2877094972067039, 0.5681818181818182, 'fare <= 19.262\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not survived'),
#  Text(0.28212290502793297, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.29329608938547486, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.2849162011173184, 0.6136363636363636, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.2988826815642458, 0.8409090909090909, 'parch <= 0.5\ngini = 0.175\nsamples = 31\nvalue = [28, 3]\nclass = Not survived'),
#  Text(0.2849162011173184, 0.7954545454545454, 'sibsp <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.27932960893854747, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.2905027932960894, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3128491620111732, 0.7954545454545454, 'age <= 5.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]\nclass = Not survived'),
#  Text(0.3016759776536313, 0.75, 'age <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.29608938547486036, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.30726256983240224, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3240223463687151, 0.75, 'parch <= 4.5\ngini = 0.071\nsamples = 27\nvalue = [26, 1]\nclass = Not survived'),
#  Text(0.31843575418994413, 0.7045454545454546, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Not survived'),
#  Text(0.329608938547486, 0.7045454545454546, 'age <= 38.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not survived'),
#  Text(0.3240223463687151, 0.6590909090909091, 'parch <= 7.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.31843575418994413, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.329608938547486, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.33519553072625696, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.4843825015275838, 0.9318181818181818, 'age <= 9.5\ngini = 0.288\nsamples = 677\nvalue = [559, 118]\nclass = Not survived'),
#  Text(0.3715083798882682, 0.8863636363636364, 'sibsp <= 2.5\ngini = 0.48\nsamples = 35\nvalue = [14, 21]\nclass = Survived'),
#  Text(0.35195530726256985, 0.8409090909090909, 'age <= 0.792\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = Survived'),
#  Text(0.3407821229050279, 0.7954545454545454, 'fare <= 11.146\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.33519553072625696, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3463687150837989, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.36312849162011174, 0.7954545454545454, 'embarked <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]\nclass = Survived'),
#  Text(0.3575418994413408, 0.75, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Survived'),
#  Text(0.3687150837988827, 0.75, 'fare <= 26.125\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.36312849162011174, 0.7045454545454546, 'age <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.3575418994413408, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.3687150837988827, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3743016759776536, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.39106145251396646, 0.8409090909090909, 'age <= 3.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not survived'),
#  Text(0.3854748603351955, 0.7954545454545454, 'age <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.39106145251396646, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.39664804469273746, 0.7954545454545454, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not survived'),
#  Text(0.5972566231668994, 0.8863636363636364, 'pclass <= 1.5\ngini = 0.257\nsamples = 642\nvalue = [545, 97]\nclass = Not survived'),
#  Text(0.5157122905027933, 0.8409090909090909, 'age <= 54.5\ngini = 0.406\nsamples = 141\nvalue = [101, 40]\nclass = Not survived'),
#  Text(0.46717877094972066, 0.7954545454545454, 'sibsp <= 0.5\ngini = 0.433\nsamples = 120\nvalue = [82, 38]\nclass = Not survived'),
#  Text(0.41480446927374304, 0.75, 'embarked <= 0.5\ngini = 0.378\nsamples = 79\nvalue = [59, 20]\nclass = Not survived'),
#  Text(0.3854748603351955, 0.7045454545454546, 'fare <= 41.0\ngini = 0.295\nsamples = 50\nvalue = [41, 9]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.6590909090909091, 'fare <= 25.962\ngini = 0.389\nsamples = 34\nvalue = [25, 9]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not survived'),
#  Text(0.3854748603351955, 0.6136363636363636, 'fare <= 37.55\ngini = 0.444\nsamples = 27\nvalue = [18, 9]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.5681818181818182, 'age <= 28.0\ngini = 0.426\nsamples = 26\nvalue = [18, 8]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3854748603351955, 0.5227272727272727, 'fare <= 26.419\ngini = 0.403\nsamples = 25\nvalue = [18, 7]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.4772727272727273, 'fare <= 26.144\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Not survived'),
#  Text(0.3687150837988827, 0.4318181818181818, 'age <= 29.941\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.36312849162011174, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.39664804469273746, 0.4772727272727273, 'age <= 47.5\ngini = 0.346\nsamples = 18\nvalue = [14, 4]\nclass = Not survived'),
#  Text(0.39106145251396646, 0.4318181818181818, 'age <= 31.441\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = Not survived'),
#  Text(0.3854748603351955, 0.38636363636363635, 'fare <= 35.25\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.3409090909090909, 'fare <= 30.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.29545454545454547, 'age <= 29.441\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.3687150837988827, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.37988826815642457, 0.25, 'fare <= 28.275\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.3743016759776536, 0.20454545454545456, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not survived'),
#  Text(0.3854748603351955, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.3854748603351955, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.39106145251396646, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.39664804469273746, 0.38636363636363635, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Not survived'),
#  Text(0.4022346368715084, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.39106145251396646, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.39106145251396646, 0.6590909090909091, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Not survived'),
#  Text(0.4441340782122905, 0.7045454545454546, 'age <= 21.5\ngini = 0.471\nsamples = 29\nvalue = [18, 11]\nclass = Not survived'),
#  Text(0.43854748603351956, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.44972067039106145, 0.6590909090909091, 'fare <= 30.598\ngini = 0.444\nsamples = 27\nvalue = [18, 9]\nclass = Not survived'),
#  Text(0.4301675977653631, 0.6136363636363636, 'fare <= 28.125\ngini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = Survived'),
#  Text(0.41899441340782123, 0.5681818181818182, 'fare <= 27.135\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Not survived'),
#  Text(0.4134078212290503, 0.5227272727272727, 'age <= 27.441\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.40782122905027934, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.41899441340782123, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.4245810055865922, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.441340782122905, 0.5681818181818182, 'parch <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Survived'),
#  Text(0.43575418994413406, 0.5227272727272727, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Survived'),
#  Text(0.44692737430167595, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.4692737430167598, 0.6136363636363636, 'fare <= 379.925\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not survived'),
#  Text(0.46368715083798884, 0.5681818181818182, 'age <= 28.441\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Not survived'),
#  Text(0.4581005586592179, 0.5227272727272727, 'fare <= 77.965\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.45251396648044695, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.46368715083798884, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.4692737430167598, 0.5227272727272727, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Not survived'),
#  Text(0.4748603351955307, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5195530726256983, 0.75, 'age <= 52.5\ngini = 0.493\nsamples = 41\nvalue = [23, 18]\nclass = Not survived'),
#  Text(0.5139664804469274, 0.7045454545454546, 'fare <= 58.5\ngini = 0.484\nsamples = 39\nvalue = [23, 16]\nclass = Not survived'),
#  Text(0.5027932960893855, 0.6590909090909091, 'embarked <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [6, 8]\nclass = Survived'),
#  Text(0.4972067039106145, 0.6136363636363636, 'fare <= 56.45\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Not survived'),
#  Text(0.49162011173184356, 0.5681818181818182, 'parch <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Not survived'),
#  Text(0.4860335195530726, 0.5227272727272727, 'age <= 41.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Not survived'),
#  Text(0.4748603351955307, 0.4772727272727273, 'age <= 29.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.4692737430167598, 0.4318181818181818, 'age <= 23.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.46368715083798884, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.4748603351955307, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.48044692737430167, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.4972067039106145, 0.4772727272727273, 'age <= 49.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not survived'),
#  Text(0.49162011173184356, 0.4318181818181818, 'age <= 45.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.4860335195530726, 0.38636363636363635, 'fare <= 52.277\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.48044692737430167, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.49162011173184356, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.4972067039106145, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5027932960893855, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.4972067039106145, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5027932960893855, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5083798882681564, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.5251396648044693, 0.6590909090909091, 'fare <= 74.006\ngini = 0.435\nsamples = 25\nvalue = [17, 8]\nclass = Not survived'),
#  Text(0.5195530726256983, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.5307262569832403, 0.6136363636363636, 'age <= 15.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = Not survived'),
#  Text(0.5251396648044693, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5363128491620112, 0.5681818181818182, 'fare <= 135.64\ngini = 0.455\nsamples = 20\nvalue = [13, 7]\nclass = Not survived'),
#  Text(0.5307262569832403, 0.5227272727272727, 'fare <= 122.267\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = Not survived'),
#  Text(0.5251396648044693, 0.4772727272727273, 'fare <= 98.752\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = Not survived'),
#  Text(0.5195530726256983, 0.4318181818181818, 'age <= 26.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Not survived'),
#  Text(0.5139664804469274, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.5251396648044693, 0.38636363636363635, 'age <= 37.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Not survived'),
#  Text(0.5195530726256983, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.5307262569832403, 0.3409090909090909, 'fare <= 78.19\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Not survived'),
#  Text(0.5251396648044693, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5363128491620112, 0.29545454545454547, 'fare <= 86.29\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.5307262569832403, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.5418994413407822, 0.25, 'sibsp <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.5363128491620112, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.547486033519553, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.5307262569832403, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.5363128491620112, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.5418994413407822, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.5251396648044693, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.5642458100558659, 0.7954545454545454, 'age <= 75.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]\nclass = Not survived'),
#  Text(0.5586592178770949, 0.75, 'age <= 56.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Not survived'),
#  Text(0.553072625698324, 0.7045454545454546, 'fare <= 42.75\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not survived'),
#  Text(0.547486033519553, 0.6590909090909091, 'fare <= 33.098\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.5418994413407822, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.553072625698324, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5586592178770949, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.5642458100558659, 0.7045454545454546, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not survived'),
#  Text(0.5698324022346368, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6788009558310056, 0.8409090909090909, 'pclass <= 2.5\ngini = 0.202\nsamples = 501\nvalue = [444, 57]\nclass = Not survived'),
#  Text(0.6256983240223464, 0.7954545454545454, 'age <= 42.5\ngini = 0.115\nsamples = 131\nvalue = [123, 8]\nclass = Not survived'),
#  Text(0.6201117318435754, 0.75, 'age <= 41.5\ngini = 0.133\nsamples = 112\nvalue = [104, 8]\nclass = Not survived'),
#  Text(0.6089385474860335, 0.7045454545454546, 'age <= 34.5\ngini = 0.122\nsamples = 107\nvalue = [100, 7]\nclass = Not survived'),
#  Text(0.6033519553072626, 0.6590909090909091, 'embarked <= 0.5\ngini = 0.143\nsamples = 90\nvalue = [83, 7]\nclass = Not survived'),
#  Text(0.5810055865921788, 0.6136363636363636, 'age <= 31.5\ngini = 0.12\nsamples = 78\nvalue = [73, 5]\nclass = Not survived'),
#  Text(0.5642458100558659, 0.5681818181818182, 'parch <= 0.5\ngini = 0.088\nsamples = 65\nvalue = [62, 3]\nclass = Not survived'),
#  Text(0.553072625698324, 0.5227272727272727, 'fare <= 11.0\ngini = 0.064\nsamples = 60\nvalue = [58, 2]\nclass = Not survived'),
#  Text(0.547486033519553, 0.4772727272727273, 'age <= 24.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Not survived'),
#  Text(0.5418994413407822, 0.4318181818181818, 'age <= 20.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Not survived'),
#  Text(0.5363128491620112, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.547486033519553, 0.38636363636363635, 'age <= 22.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.5418994413407822, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.553072625698324, 0.3409090909090909, 'age <= 23.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.547486033519553, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.5586592178770949, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.553072625698324, 0.4318181818181818, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not survived'),
#  Text(0.5586592178770949, 0.4772727272727273, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]\nclass = Not survived'),
#  Text(0.5754189944134078, 0.5227272727272727, 'age <= 27.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.5698324022346368, 0.4772727272727273, 'age <= 22.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.5642458100558659, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.5754189944134078, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.5810055865921788, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.5977653631284916, 0.5681818181818182, 'fare <= 12.637\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Not survived'),
#  Text(0.5921787709497207, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.6033519553072626, 0.5227272727272727, 'sibsp <= 1.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Not survived'),
#  Text(0.5977653631284916, 0.4772727272727273, 'age <= 33.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Not survived'),
#  Text(0.5865921787709497, 0.4318181818181818, 'fare <= 19.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.5810055865921788, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.5921787709497207, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6089385474860335, 0.4318181818181818, 'sibsp <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Not survived'),
#  Text(0.6033519553072626, 0.38636363636363635, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.6145251396648045, 0.38636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.6089385474860335, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.6256983240223464, 0.6136363636363636, 'fare <= 14.448\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Not survived'),
#  Text(0.6201117318435754, 0.5681818181818182, 'fare <= 12.285\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.6145251396648045, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.6256983240223464, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.6312849162011173, 0.5681818181818182, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not survived'),
#  Text(0.6145251396648045, 0.6590909090909091, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = Not survived'),
#  Text(0.6312849162011173, 0.7045454545454546, 'fare <= 20.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.6256983240223464, 0.6590909090909091, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.6368715083798883, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.6312849162011173, 0.75, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Not survived'),
#  Text(0.7319035876396648, 0.7954545454545454, 'fare <= 7.535\ngini = 0.23\nsamples = 370\nvalue = [321, 49]\nclass = Not survived'),
#  Text(0.6703910614525139, 0.75, 'age <= 25.75\ngini = 0.128\nsamples = 73\nvalue = [68, 5]\nclass = Not survived'),
#  Text(0.6536312849162011, 0.7045454545454546, 'fare <= 7.133\ngini = 0.238\nsamples = 29\nvalue = [25, 4]\nclass = Not survived'),
#  Text(0.6480446927374302, 0.6590909090909091, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not survived'),
#  Text(0.659217877094972, 0.6590909090909091, 'fare <= 7.183\ngini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Not survived'),
#  Text(0.6536312849162011, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.664804469273743, 0.6136363636363636, 'fare <= 7.24\ngini = 0.278\nsamples = 18\nvalue = [15, 3]\nclass = Not survived'),
#  Text(0.659217877094972, 0.5681818181818182, 'age <= 19.25\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not survived'),
#  Text(0.6536312849162011, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.664804469273743, 0.5227272727272727, 'fare <= 7.227\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Not survived'),
#  Text(0.6536312849162011, 0.4772727272727273, 'age <= 21.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.6480446927374302, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.659217877094972, 0.4318181818181818, 'age <= 22.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.6536312849162011, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.664804469273743, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.6759776536312849, 0.4772727272727273, 'age <= 21.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.6703910614525139, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6815642458100558, 0.4318181818181818, 'age <= 24.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.6759776536312849, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.6871508379888268, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.6703910614525139, 0.5681818181818182, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not survived'),
#  Text(0.6871508379888268, 0.7045454545454546, 'fare <= 7.052\ngini = 0.044\nsamples = 44\nvalue = [43, 1]\nclass = Not survived'),
#  Text(0.6815642458100558, 0.6590909090909091, 'fare <= 7.048\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Not survived'),
#  Text(0.6759776536312849, 0.6136363636363636, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Not survived'),
#  Text(0.6871508379888268, 0.6136363636363636, 'age <= 32.441\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not survived'),
#  Text(0.6815642458100558, 0.5681818181818182, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.6927374301675978, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.6927374301675978, 0.6590909090909091, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = Not survived'),
#  Text(0.7934161138268156, 0.75, 'fare <= 7.835\ngini = 0.252\nsamples = 297\nvalue = [253, 44]\nclass = Not survived'),
#  Text(0.7402234636871509, 0.7045454545454546, 'age <= 27.0\ngini = 0.367\nsamples = 66\nvalue = [50, 16]\nclass = Not survived'),
#  Text(0.7150837988826816, 0.6590909090909091, 'age <= 20.0\ngini = 0.459\nsamples = 28\nvalue = [18, 10]\nclass = Not survived'),
#  Text(0.7094972067039106, 0.6136363636363636, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not survived'),
#  Text(0.7206703910614525, 0.6136363636363636, 'fare <= 7.6\ngini = 0.491\nsamples = 23\nvalue = [13, 10]\nclass = Not survived'),
#  Text(0.7150837988826816, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7262569832402235, 0.5681818181818182, 'fare <= 7.81\ngini = 0.483\nsamples = 22\nvalue = [13, 9]\nclass = Not survived'),
#  Text(0.7206703910614525, 0.5227272727272727, 'embarked <= 1.0\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = Not survived'),
#  Text(0.7150837988826816, 0.4772727272727273, 'fare <= 7.798\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = Not survived'),
#  Text(0.7094972067039106, 0.4318181818181818, 'age <= 21.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]\nclass = Not survived'),
#  Text(0.6983240223463687, 0.38636363636363635, 'fare <= 7.785\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.6927374301675978, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.7039106145251397, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.7206703910614525, 0.38636363636363635, 'age <= 22.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = Not survived'),
#  Text(0.7150837988826816, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.7262569832402235, 0.3409090909090909, 'age <= 23.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = Not survived'),
#  Text(0.7206703910614525, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7318435754189944, 0.29545454545454547, 'age <= 24.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = Not survived'),
#  Text(0.7262569832402235, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.7374301675977654, 0.25, 'fare <= 7.785\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.7318435754189944, 0.20454545454545456, 'age <= 25.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Not survived'),
#  Text(0.7262569832402235, 0.1590909090909091, 'fare <= 7.713\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Not survived'),
#  Text(0.7206703910614525, 0.11363636363636363, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.7318435754189944, 0.11363636363636363, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.7374301675977654, 0.1590909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.7430167597765364, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7206703910614525, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.7262569832402235, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.7318435754189944, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.7653631284916201, 0.6590909090909091, 'age <= 32.5\ngini = 0.266\nsamples = 38\nvalue = [32, 6]\nclass = Not survived'),
#  Text(0.7597765363128491, 0.6136363636363636, 'age <= 31.5\ngini = 0.312\nsamples = 31\nvalue = [25, 6]\nclass = Not survived'),
#  Text(0.7486033519553073, 0.5681818181818182, 'fare <= 7.744\ngini = 0.245\nsamples = 28\nvalue = [24, 4]\nclass = Not survived'),
#  Text(0.7430167597765364, 0.5227272727272727, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Not survived'),
#  Text(0.7541899441340782, 0.5227272727272727, 'embarked <= 1.0\ngini = 0.298\nsamples = 22\nvalue = [18, 4]\nclass = Not survived'),
#  Text(0.7486033519553073, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.7597765363128491, 0.4772727272727273, 'sibsp <= 0.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Not survived'),
#  Text(0.7541899441340782, 0.4318181818181818, 'age <= 30.441\ngini = 0.36\nsamples = 17\nvalue = [13, 4]\nclass = Not survived'),
#  Text(0.7486033519553073, 0.38636363636363635, 'gini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = Not survived'),
#  Text(0.7597765363128491, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.7653631284916201, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.770949720670391, 0.5681818181818182, 'embarked <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7653631284916201, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.776536312849162, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.770949720670391, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not survived'),
#  Text(0.8466087639664804, 0.7045454545454546, 'age <= 28.75\ngini = 0.213\nsamples = 231\nvalue = [203, 28]\nclass = Not survived'),
#  Text(0.8100558659217877, 0.6590909090909091, 'age <= 20.5\ngini = 0.131\nsamples = 99\nvalue = [92, 7]\nclass = Not survived'),
#  Text(0.7988826815642458, 0.6136363636363636, 'fare <= 12.848\ngini = 0.231\nsamples = 45\nvalue = [39, 6]\nclass = Not survived'),
#  Text(0.7932960893854749, 0.5681818181818182, 'age <= 15.0\ngini = 0.337\nsamples = 28\nvalue = [22, 6]\nclass = Not survived'),
#  Text(0.7877094972067039, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.7988826815642458, 0.5227272727272727, 'fare <= 8.104\ngini = 0.26\nsamples = 26\nvalue = [22, 4]\nclass = Not survived'),
#  Text(0.7932960893854749, 0.4772727272727273, 'fare <= 7.91\ngini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = Not survived'),
#  Text(0.7877094972067039, 0.4318181818181818, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not survived'),
#  Text(0.7988826815642458, 0.4318181818181818, 'fare <= 7.988\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Survived'),
#  Text(0.7932960893854749, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8044692737430168, 0.38636363636363635, 'age <= 18.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.7988826815642458, 0.3409090909090909, 'age <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.7932960893854749, 0.29545454545454547, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.8044692737430168, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8100558659217877, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.8044692737430168, 0.4772727272727273, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not survived'),
#  Text(0.8044692737430168, 0.5681818181818182, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = Not survived'),
#  Text(0.8212290502793296, 0.6136363636363636, 'age <= 26.5\ngini = 0.036\nsamples = 54\nvalue = [53, 1]\nclass = Not survived'),
#  Text(0.8156424581005587, 0.5681818181818182, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = Not survived'),
#  Text(0.8268156424581006, 0.5681818181818182, 'age <= 27.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Not survived'),
#  Text(0.8212290502793296, 0.5227272727272727, 'fare <= 8.279\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not survived'),
#  Text(0.8156424581005587, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.8268156424581006, 0.4772727272727273, 'embarked <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not survived'),
#  Text(0.8212290502793296, 0.4318181818181818, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.8324022346368715, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.8324022346368715, 0.5227272727272727, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not survived'),
#  Text(0.8831616620111732, 0.6590909090909091, 'age <= 29.441\ngini = 0.268\nsamples = 132\nvalue = [111, 21]\nclass = Not survived'),
#  Text(0.8547486033519553, 0.6136363636363636, 'fare <= 9.492\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Not survived'),
#  Text(0.8491620111731844, 0.5681818181818182, 'embarked <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.8435754189944135, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived'),
#  Text(0.8547486033519553, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.8603351955307262, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.911574720670391, 0.6136363636363636, 'fare <= 51.698\ngini = 0.247\nsamples = 125\nvalue = [107, 18]\nclass = Not survived'),
#  Text(0.8870460893854749, 0.5681818181818182, 'fare <= 7.892\ngini = 0.224\nsamples = 117\nvalue = [102, 15]\nclass = Not survived'),
#  Text(0.8659217877094972, 0.5227272727272727, 'age <= 32.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.8603351955307262, 0.4772727272727273, 'embarked <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.8547486033519553, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Survived'),
#  Text(0.8659217877094972, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.8715083798882681, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not survived'),
#  Text(0.9081703910614525, 0.5227272727272727, 'fare <= 7.91\ngini = 0.207\nsamples = 111\nvalue = [98, 13]\nclass = Not survived'),
#  Text(0.9025837988826816, 0.4772727272727273, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Not survived'),
#  Text(0.9137569832402235, 0.4772727272727273, 'fare <= 7.988\ngini = 0.245\nsamples = 91\nvalue = [78, 13]\nclass = Not survived'),
#  Text(0.8770949720670391, 0.4318181818181818, 'age <= 31.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = Not survived'),
#  Text(0.8715083798882681, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.88268156424581, 0.38636363636363635, 'age <= 41.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Not survived'),
#  Text(0.8770949720670391, 0.3409090909090909, 'sibsp <= 1.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.8715083798882681, 0.29545454545454547, 'age <= 35.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Not survived'),
#  Text(0.8659217877094972, 0.25, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.8770949720670391, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.88268156424581, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.888268156424581, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9504189944134078, 0.4318181818181818, 'embarked <= 0.5\ngini = 0.193\nsamples = 83\nvalue = [74, 9]\nclass = Not survived'),
#  Text(0.9231843575418994, 0.38636363636363635, 'parch <= 0.5\ngini = 0.138\nsamples = 67\nvalue = [62, 5]\nclass = Not survived'),
#  Text(0.9175977653631285, 0.3409090909090909, 'age <= 29.941\ngini = 0.165\nsamples = 55\nvalue = [50, 5]\nclass = Not survived'),
#  Text(0.8938547486033519, 0.29545454545454547, 'fare <= 8.081\ngini = 0.08\nsamples = 24\nvalue = [23, 1]\nclass = Not survived'),
#  Text(0.888268156424581, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Not survived'),
#  Text(0.8994413407821229, 0.25, 'fare <= 8.388\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Not survived'),
#  Text(0.8938547486033519, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9050279329608939, 0.20454545454545456, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not survived'),
#  Text(0.9413407821229051, 0.29545454545454547, 'fare <= 16.75\ngini = 0.225\nsamples = 31\nvalue = [27, 4]\nclass = Not survived'),
#  Text(0.9273743016759777, 0.25, 'age <= 32.5\ngini = 0.191\nsamples = 28\nvalue = [25, 3]\nclass = Not survived'),
#  Text(0.9162011173184358, 0.20454545454545456, 'fare <= 12.675\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Not survived'),
#  Text(0.9106145251396648, 0.1590909090909091, 'fare <= 8.931\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Not survived'),
#  Text(0.9050279329608939, 0.11363636363636363, 'age <= 31.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Not survived'),
#  Text(0.8994413407821229, 0.06818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.9106145251396648, 0.06818181818181818, 'fare <= 8.206\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.9050279329608939, 0.022727272727272728, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Not survived'),
#  Text(0.9162011173184358, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.9162011173184358, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9217877094972067, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.9385474860335196, 0.20454545454545456, 'age <= 44.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Not survived'),
#  Text(0.9329608938547486, 0.1590909090909091, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not survived'),
#  Text(0.9441340782122905, 0.1590909090909091, 'age <= 46.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Not survived'),
#  Text(0.9385474860335196, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9497206703910615, 0.11363636363636363, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Not survived'),
#  Text(0.9553072625698324, 0.25, 'sibsp <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.9497206703910615, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.9608938547486033, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9287709497206704, 0.3409090909090909, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not survived'),
#  Text(0.9776536312849162, 0.38636363636363635, 'parch <= 0.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = Not survived'),
#  Text(0.9664804469273743, 0.3409090909090909, 'sibsp <= 1.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not survived'),
#  Text(0.9608938547486033, 0.29545454545454547, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not survived'),
#  Text(0.9720670391061452, 0.29545454545454547, 'embarked <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Not survived'),
#  Text(0.9664804469273743, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not survived'),
#  Text(0.9776536312849162, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9888268156424581, 0.3409090909090909, 'age <= 39.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.9832402234636871, 0.29545454545454547, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Survived'),
#  Text(0.994413407821229, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not survived'),
#  Text(0.9361033519553073, 0.5681818181818182, 'parch <= 1.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Not survived'),
#  Text(0.9305167597765364, 0.5227272727272727, 'age <= 30.941\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Survived'),
#  Text(0.9249301675977654, 0.4772727272727273, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Survived'),
#  Text(0.9361033519553073, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Survived'),
#  Text(0.9416899441340782, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not survived')]

# %% [markdown]
# Decision trees nos dan muchas posibilidades de mejorar sus resultados, trabajando con sus hiperparámetros

# %%
# Aumenta el número de muestras mínimas para continuar un nodo
DT = tree.DecisionTreeClassifier(random_state=rn_state, min_samples_leaf=10)
DT = DT.fit(X_train, y_train)
print('test accuracy: %.2f' % DT.score(X_test, y_test))
print('test precision: %.2f' % precision_score(y_test, y_predicted))
print('test recall: %.2f' % recall_score(y_test, y_predicted))
print('test f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# test accuracy: 0.77
# test precision: 0.81
# test recall: 0.71
# test f1: 0.76

# %%
tree.plot_tree(DT,
               feature_names=X_train.columns.tolist(),
               class_names=['Not survived', 'Survived'],
               filled=True,
               rounded=True)
# Out:
# [Text(0.3035126879699248, 0.9615384615384616, 'sex <= 0.5\ngini = 0.463\nsamples = 1047\nvalue = [665, 382]\nclass = Not survived'),
#  Text(0.18045112781954886, 0.8846153846153846, 'pclass <= 2.5\ngini = 0.409\nsamples = 370\nvalue = [106, 264]\nclass = Survived'),
#  Text(0.12030075187969924, 0.8076923076923077, 'fare <= 32.09\ngini = 0.124\nsamples = 195\nvalue = [13, 182]\nclass = Survived'),
#  Text(0.09022556390977443, 0.7307692307692307, 'parch <= 1.5\ngini = 0.223\nsamples = 86\nvalue = [11, 75]\nclass = Survived'),
#  Text(0.07518796992481203, 0.6538461538461539, 'age <= 35.5\ngini = 0.248\nsamples = 76\nvalue = [11, 65]\nclass = Survived'),
#  Text(0.045112781954887216, 0.5769230769230769, 'age <= 29.441\ngini = 0.204\nsamples = 52\nvalue = [6, 46]\nclass = Survived'),
#  Text(0.03007518796992481, 0.5, 'fare <= 22.0\ngini = 0.266\nsamples = 38\nvalue = [6, 32]\nclass = Survived'),
#  Text(0.015037593984962405, 0.4230769230769231, 'gini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = Survived'),
#  Text(0.045112781954887216, 0.4230769230769231, 'age <= 22.5\ngini = 0.159\nsamples = 23\nvalue = [2, 21]\nclass = Survived'),
#  Text(0.03007518796992481, 0.34615384615384615, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Survived'),
#  Text(0.06015037593984962, 0.34615384615384615, 'gini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = Survived'),
#  Text(0.06015037593984962, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Survived'),
#  Text(0.10526315789473684, 0.5769230769230769, 'fare <= 25.965\ngini = 0.33\nsamples = 24\nvalue = [5, 19]\nclass = Survived'),
#  Text(0.09022556390977443, 0.5, 'gini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Survived'),
#  Text(0.12030075187969924, 0.5, 'gini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Survived'),
#  Text(0.10526315789473684, 0.6538461538461539, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = Survived'),
#  Text(0.15037593984962405, 0.7307692307692307, 'parch <= 1.5\ngini = 0.036\nsamples = 109\nvalue = [2, 107]\nclass = Survived'),
#  Text(0.13533834586466165, 0.6538461538461539, 'gini = 0.0\nsamples = 91\nvalue = [0, 91]\nclass = Survived'),
#  Text(0.16541353383458646, 0.6538461538461539, 'gini = 0.198\nsamples = 18\nvalue = [2, 16]\nclass = Survived'),
#  Text(0.24060150375939848, 0.8076923076923077, 'fare <= 23.35\ngini = 0.498\nsamples = 175\nvalue = [93, 82]\nclass = Not survived'),
#  Text(0.21052631578947367, 0.7307692307692307, 'fare <= 7.523\ngini = 0.495\nsamples = 144\nvalue = [65, 79]\nclass = Survived'),
#  Text(0.19548872180451127, 0.6538461538461539, 'gini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = Survived'),
#  Text(0.22556390977443608, 0.6538461538461539, 'fare <= 14.873\ngini = 0.499\nsamples = 134\nvalue = [64, 70]\nclass = Survived'),
#  Text(0.18796992481203006, 0.5769230769230769, 'fare <= 14.254\ngini = 0.494\nsamples = 94\nvalue = [52, 42]\nclass = Not survived'),
#  Text(0.17293233082706766, 0.5, 'age <= 19.5\ngini = 0.5\nsamples = 83\nvalue = [42, 41]\nclass = Not survived'),
#  Text(0.14285714285714285, 0.4230769230769231, 'fare <= 8.221\ngini = 0.455\nsamples = 20\nvalue = [7, 13]\nclass = Survived'),
#  Text(0.12781954887218044, 0.34615384615384615, 'gini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = Survived'),
#  Text(0.15789473684210525, 0.34615384615384615, 'gini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.20300751879699247, 0.4230769230769231, 'embarked <= 1.0\ngini = 0.494\nsamples = 63\nvalue = [35, 28]\nclass = Not survived'),
#  Text(0.18796992481203006, 0.34615384615384615, 'fare <= 8.906\ngini = 0.444\nsamples = 33\nvalue = [22, 11]\nclass = Not survived'),
#  Text(0.17293233082706766, 0.2692307692307692, 'age <= 26.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]\nclass = Not survived'),
#  Text(0.15789473684210525, 0.19230769230769232, 'gini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = Not survived'),
#  Text(0.18796992481203006, 0.19230769230769232, 'gini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Not survived'),
#  Text(0.20300751879699247, 0.2692307692307692, 'gini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = Not survived'),
#  Text(0.21804511278195488, 0.34615384615384615, 'gini = 0.491\nsamples = 30\nvalue = [13, 17]\nclass = Survived'),
#  Text(0.20300751879699247, 0.5, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Not survived'),
#  Text(0.2631578947368421, 0.5769230769230769, 'embarked <= 0.5\ngini = 0.42\nsamples = 40\nvalue = [12, 28]\nclass = Survived'),
#  Text(0.24812030075187969, 0.5, 'age <= 29.441\ngini = 0.476\nsamples = 23\nvalue = [9, 14]\nclass = Survived'),
#  Text(0.23308270676691728, 0.4230769230769231, 'gini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = Not survived'),
#  Text(0.2631578947368421, 0.4230769230769231, 'gini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = Survived'),
#  Text(0.2781954887218045, 0.5, 'gini = 0.291\nsamples = 17\nvalue = [3, 14]\nclass = Survived'),
#  Text(0.2706766917293233, 0.7307692307692307, 'fare <= 32.881\ngini = 0.175\nsamples = 31\nvalue = [28, 3]\nclass = Not survived'),
#  Text(0.2556390977443609, 0.6538461538461539, 'gini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = Not survived'),
#  Text(0.2857142857142857, 0.6538461538461539, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Not survived'),
#  Text(0.42657424812030076, 0.8846153846153846, 'age <= 9.5\ngini = 0.288\nsamples = 677\nvalue = [559, 118]\nclass = Not survived'),
#  Text(0.3458646616541353, 0.8076923076923077, 'sibsp <= 2.5\ngini = 0.48\nsamples = 35\nvalue = [14, 21]\nclass = Survived'),
#  Text(0.3308270676691729, 0.7307692307692307, 'fare <= 17.325\ngini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = Survived'),
#  Text(0.3157894736842105, 0.6538461538461539, 'gini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Survived'),
#  Text(0.3458646616541353, 0.6538461538461539, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Survived'),
#  Text(0.3609022556390977, 0.7307692307692307, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not survived'),
#  Text(0.5072838345864662, 0.8076923076923077, 'pclass <= 1.5\ngini = 0.257\nsamples = 642\nvalue = [545, 97]\nclass = Not survived'),
#  Text(0.41729323308270677, 0.7307692307692307, 'age <= 54.5\ngini = 0.406\nsamples = 141\nvalue = [101, 40]\nclass = Not survived'),
#  Text(0.37593984962406013, 0.6538461538461539, 'sibsp <= 0.5\ngini = 0.433\nsamples = 120\nvalue = [82, 38]\nclass = Not survived'),
#  Text(0.3383458646616541, 0.5769230769230769, 'embarked <= 0.5\ngini = 0.378\nsamples = 79\nvalue = [59, 20]\nclass = Not survived'),
#  Text(0.3082706766917293, 0.5, 'fare <= 41.0\ngini = 0.295\nsamples = 50\nvalue = [41, 9]\nclass = Not survived'),
#  Text(0.2932330827067669, 0.4230769230769231, 'fare <= 26.144\ngini = 0.389\nsamples = 34\nvalue = [25, 9]\nclass = Not survived'),
#  Text(0.2781954887218045, 0.34615384615384615, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not survived'),
#  Text(0.3082706766917293, 0.34615384615384615, 'age <= 31.441\ngini = 0.463\nsamples = 22\nvalue = [14, 8]\nclass = Not survived'),
#  Text(0.2932330827067669, 0.2692307692307692, 'gini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Not survived'),
#  Text(0.3233082706766917, 0.2692307692307692, 'gini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not survived'),
#  Text(0.3233082706766917, 0.4230769230769231, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Not survived'),
#  Text(0.3684210526315789, 0.5, 'fare <= 30.598\ngini = 0.471\nsamples = 29\nvalue = [18, 11]\nclass = Not survived'),
#  Text(0.3533834586466165, 0.4230769230769231, 'gini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = Survived'),
#  Text(0.38345864661654133, 0.4230769230769231, 'gini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = Not survived'),
#  Text(0.41353383458646614, 0.5769230769230769, 'fare <= 58.5\ngini = 0.493\nsamples = 41\nvalue = [23, 18]\nclass = Not survived'),
#  Text(0.39849624060150374, 0.5, 'gini = 0.48\nsamples = 15\nvalue = [6, 9]\nclass = Survived'),
#  Text(0.42857142857142855, 0.5, 'age <= 44.5\ngini = 0.453\nsamples = 26\nvalue = [17, 9]\nclass = Not survived'),
#  Text(0.41353383458646614, 0.4230769230769231, 'gini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Not survived'),
#  Text(0.44360902255639095, 0.4230769230769231, 'gini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Not survived'),
#  Text(0.45864661654135336, 0.6538461538461539, 'age <= 60.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]\nclass = Not survived'),
#  Text(0.44360902255639095, 0.5769230769230769, 'gini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Not survived'),
#  Text(0.47368421052631576, 0.5769230769230769, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Not survived'),
#  Text(0.5972744360902256, 0.7307692307692307, 'pclass <= 2.5\ngini = 0.202\nsamples = 501\nvalue = [444, 57]\nclass = Not survived'),
#  Text(0.518796992481203, 0.6538461538461539, 'age <= 42.5\ngini = 0.115\nsamples = 131\nvalue = [123, 8]\nclass = Not survived'),
#  Text(0.5037593984962406, 0.5769230769230769, 'fare <= 29.535\ngini = 0.133\nsamples = 112\nvalue = [104, 8]\nclass = Not survived'),
#  Text(0.48872180451127817, 0.5, 'embarked <= 0.5\ngini = 0.15\nsamples = 98\nvalue = [90, 8]\nclass = Not survived'),
#  Text(0.47368421052631576, 0.4230769230769231, 'age <= 21.5\ngini = 0.131\nsamples = 85\nvalue = [79, 6]\nclass = Not survived'),
#  Text(0.45864661654135336, 0.34615384615384615, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Not survived'),
#  Text(0.48872180451127817, 0.34615384615384615, 'age <= 24.5\ngini = 0.149\nsamples = 74\nvalue = [68, 6]\nclass = Not survived'),
#  Text(0.47368421052631576, 0.2692307692307692, 'gini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Not survived'),
#  Text(0.5037593984962406, 0.2692307692307692, 'sibsp <= 0.5\ngini = 0.119\nsamples = 63\nvalue = [59, 4]\nclass = Not survived'),
#  Text(0.48872180451127817, 0.19230769230769232, 'age <= 33.5\ngini = 0.081\nsamples = 47\nvalue = [45, 2]\nclass = Not survived'),
#  Text(0.47368421052631576, 0.11538461538461539, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]\nclass = Not survived'),
#  Text(0.5037593984962406, 0.11538461538461539, 'gini = 0.208\nsamples = 17\nvalue = [15, 2]\nclass = Not survived'),
#  Text(0.518796992481203, 0.19230769230769232, 'gini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = Not survived'),
#  Text(0.5037593984962406, 0.4230769230769231, 'gini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Not survived'),
#  Text(0.518796992481203, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not survived'),
#  Text(0.5338345864661654, 0.5769230769230769, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Not survived'),
#  Text(0.6757518796992481, 0.6538461538461539, 'fare <= 7.535\ngini = 0.23\nsamples = 370\nvalue = [321, 49]\nclass = Not survived'),
#  Text(0.5789473684210527, 0.5769230769230769, 'age <= 25.75\ngini = 0.128\nsamples = 73\nvalue = [68, 5]\nclass = Not survived'),
#  Text(0.5488721804511278, 0.5, 'fare <= 7.133\ngini = 0.238\nsamples = 29\nvalue = [25, 4]\nclass = Not survived'),
#  Text(0.5338345864661654, 0.4230769230769231, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Not survived'),
#  Text(0.5639097744360902, 0.4230769230769231, 'gini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = Not survived'),
#  Text(0.6090225563909775, 0.5, 'fare <= 7.052\ngini = 0.044\nsamples = 44\nvalue = [43, 1]\nclass = Not survived'),
#  Text(0.5939849624060151, 0.4230769230769231, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Not survived'),
#  Text(0.6240601503759399, 0.4230769230769231, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = Not survived'),
#  Text(0.7725563909774437, 0.5769230769230769, 'fare <= 7.835\ngini = 0.252\nsamples = 297\nvalue = [253, 44]\nclass = Not survived'),
#  Text(0.6842105263157895, 0.5, 'age <= 27.0\ngini = 0.367\nsamples = 66\nvalue = [50, 16]\nclass = Not survived'),
#  Text(0.6541353383458647, 0.4230769230769231, 'age <= 22.5\ngini = 0.459\nsamples = 28\nvalue = [18, 10]\nclass = Not survived'),
#  Text(0.6390977443609023, 0.34615384615384615, 'gini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = Not survived'),
#  Text(0.6691729323308271, 0.34615384615384615, 'gini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = Not survived'),
#  Text(0.7142857142857143, 0.4230769230769231, 'age <= 31.5\ngini = 0.266\nsamples = 38\nvalue = [32, 6]\nclass = Not survived'),
#  Text(0.6992481203007519, 0.34615384615384615, 'gini = 0.245\nsamples = 28\nvalue = [24, 4]\nclass = Not survived'),
#  Text(0.7293233082706767, 0.34615384615384615, 'gini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Not survived'),
#  Text(0.8609022556390977, 0.5, 'age <= 28.75\ngini = 0.213\nsamples = 231\nvalue = [203, 28]\nclass = Not survived'),
#  Text(0.7894736842105263, 0.4230769230769231, 'age <= 20.5\ngini = 0.131\nsamples = 99\nvalue = [92, 7]\nclass = Not survived'),
#  Text(0.7593984962406015, 0.34615384615384615, 'fare <= 12.848\ngini = 0.231\nsamples = 45\nvalue = [39, 6]\nclass = Not survived'),
#  Text(0.7443609022556391, 0.2692307692307692, 'fare <= 8.104\ngini = 0.337\nsamples = 28\nvalue = [22, 6]\nclass = Not survived'),
#  Text(0.7293233082706767, 0.19230769230769232, 'gini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = Not survived'),
#  Text(0.7593984962406015, 0.19230769230769232, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not survived'),
#  Text(0.7744360902255639, 0.2692307692307692, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = Not survived'),
#  Text(0.8195488721804511, 0.34615384615384615, 'age <= 26.5\ngini = 0.036\nsamples = 54\nvalue = [53, 1]\nclass = Not survived'),
#  Text(0.8045112781954887, 0.2692307692307692, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = Not survived'),
#  Text(0.8345864661654135, 0.2692307692307692, 'gini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Not survived'),
#  Text(0.9323308270676691, 0.4230769230769231, 'fare <= 21.852\ngini = 0.268\nsamples = 132\nvalue = [111, 21]\nclass = Not survived'),
#  Text(0.8947368421052632, 0.34615384615384615, 'age <= 29.941\ngini = 0.234\nsamples = 111\nvalue = [96, 15]\nclass = Not survived'),
#  Text(0.8646616541353384, 0.2692307692307692, 'embarked <= 0.5\ngini = 0.165\nsamples = 55\nvalue = [50, 5]\nclass = Not survived'),
#  Text(0.849624060150376, 0.19230769230769232, 'fare <= 8.081\ngini = 0.13\nsamples = 43\nvalue = [40, 3]\nclass = Not survived'),
#  Text(0.8345864661654135, 0.11538461538461539, 'fare <= 7.973\ngini = 0.067\nsamples = 29\nvalue = [28, 1]\nclass = Not survived'),
#  Text(0.8195488721804511, 0.038461538461538464, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Not survived'),
#  Text(0.849624060150376, 0.038461538461538464, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not survived'),
#  Text(0.8646616541353384, 0.11538461538461539, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not survived'),
#  Text(0.8796992481203008, 0.19230769230769232, 'gini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Not survived'),
#  Text(0.924812030075188, 0.2692307692307692, 'age <= 32.5\ngini = 0.293\nsamples = 56\nvalue = [46, 10]\nclass = Not survived'),
#  Text(0.9097744360902256, 0.19230769230769232, 'gini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = Not survived'),
#  Text(0.9398496240601504, 0.19230769230769232, 'age <= 36.25\ngini = 0.21\nsamples = 42\nvalue = [37, 5]\nclass = Not survived'),
#  Text(0.924812030075188, 0.11538461538461539, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Not survived'),
#  Text(0.9548872180451128, 0.11538461538461539, 'age <= 40.75\ngini = 0.293\nsamples = 28\nvalue = [23, 5]\nclass = Not survived'),
#  Text(0.9398496240601504, 0.038461538461538464, 'gini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not survived'),
#  Text(0.9699248120300752, 0.038461538461538464, 'gini = 0.208\nsamples = 17\nvalue = [15, 2]\nclass = Not survived'),
#  Text(0.9699248120300752, 0.34615384615384615, 'fare <= 29.587\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = Not survived'),
#  Text(0.9548872180451128, 0.2692307692307692, 'gini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Not survived'),
#  Text(0.9849624060150376, 0.2692307692307692, 'gini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Not survived')]

# %% [markdown]
# O limitando su profundidad

# %%
DT = tree.DecisionTreeClassifier(random_state=rn_state, max_depth=3)
DT = DT.fit(X_train, y_train)
print('test accuracy: %.2f' % DT.score(X_test, y_test))
print('test precision: %.2f' % precision_score(y_test, y_predicted))
print('test recall: %.2f' % recall_score(y_test, y_predicted))
print('test f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# test accuracy: 0.78
# test precision: 0.81
# test recall: 0.71
# test f1: 0.76

# %%
tree.plot_tree(DT,
               feature_names=X_train.columns.tolist(),
               class_names=['Not survived', 'Survived'],
               filled=True,
               rounded=True)
# Out:
# [Text(0.5, 0.875, 'sex <= 0.5\ngini = 0.463\nsamples = 1047\nvalue = [665, 382]\nclass = Not survived'),
#  Text(0.25, 0.625, 'pclass <= 2.5\ngini = 0.409\nsamples = 370\nvalue = [106, 264]\nclass = Survived'),
#  Text(0.125, 0.375, 'fare <= 32.09\ngini = 0.124\nsamples = 195\nvalue = [13, 182]\nclass = Survived'),
#  Text(0.0625, 0.125, 'gini = 0.223\nsamples = 86\nvalue = [11, 75]\nclass = Survived'),
#  Text(0.1875, 0.125, 'gini = 0.036\nsamples = 109\nvalue = [2, 107]\nclass = Survived'),
#  Text(0.375, 0.375, 'fare <= 23.35\ngini = 0.498\nsamples = 175\nvalue = [93, 82]\nclass = Not survived'),
#  Text(0.3125, 0.125, 'gini = 0.495\nsamples = 144\nvalue = [65, 79]\nclass = Survived'),
#  Text(0.4375, 0.125, 'gini = 0.175\nsamples = 31\nvalue = [28, 3]\nclass = Not survived'),
#  Text(0.75, 0.625, 'age <= 9.5\ngini = 0.288\nsamples = 677\nvalue = [559, 118]\nclass = Not survived'),
#  Text(0.625, 0.375, 'sibsp <= 2.5\ngini = 0.48\nsamples = 35\nvalue = [14, 21]\nclass = Survived'),
#  Text(0.5625, 0.125, 'gini = 0.227\nsamples = 23\nvalue = [3, 20]\nclass = Survived'),
#  Text(0.6875, 0.125, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Not survived'),
#  Text(0.875, 0.375, 'pclass <= 1.5\ngini = 0.257\nsamples = 642\nvalue = [545, 97]\nclass = Not survived'),
#  Text(0.8125, 0.125, 'gini = 0.406\nsamples = 141\nvalue = [101, 40]\nclass = Not survived'),
#  Text(0.9375, 0.125, 'gini = 0.202\nsamples = 501\nvalue = [444, 57]\nclass = Not survived')]

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(random_state=rn_state)
random_forest = random_forest.fit(X_train, y_train)
print('test accuracy: %.2f' % random_forest.score(X_test, y_test))
print('test precision: %.2f' % precision_score(y_test, y_predicted))
print('test recall: %.2f' % recall_score(y_test, y_predicted))
print('test f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# test accuracy: 0.79
# test precision: 0.81
# test recall: 0.71
# test f1: 0.76

# %% [markdown]
# Vemos una mejora notable contra arboles de decisión. Y esto se debe a que random forest combina varios arboles de decisión, por defecto 100

# %%
len(random_forest.estimators_)
# Out:
# 100

# %% [markdown]
# Y podemos observar cada árbol y ver como cada uno empieza a especializarse en un tipo de dato

# %%
for decision_tree in random_forest.estimators_[:3]:
    tree.plot_tree(decision_tree,
                    feature_names=X_train.columns.tolist(),
                    class_names=['Not survived', 'Survived'],
                    max_depth=1)
    plt.show()

# %% [markdown]
# Esto es el efecto de bootstrap

# %% [markdown]
# ## SVM

# %% [markdown]
# Dejando atrás a los modelos de ensemble, podemos pasar a los support vector machine. Que una vez más se cargan y entrenan de forma similar

# %%
from sklearn.svm import SVC
svc = SVC(random_state=rn_state, kernel='linear')
svc = svc.fit(X_train, y_train)
print('test accuracy: %.2f' % random_forest.score(X_test, y_test))
print('test precision: %.2f' % precision_score(y_test, y_predicted))
print('test recall: %.2f' % recall_score(y_test, y_predicted))
print('test f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# test accuracy: 0.79
# test precision: 0.81
# test recall: 0.71
# test f1: 0.76

# %% [markdown]
# Podemos ver un mapa de svc, pero necesitamos usar sólo dos dimensiones

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_iris = pd.read_csv('IRIS.csv')
X = np.array(df_iris)[:, :2]  # we only take the first two features. We could
                    # avoid this ugly slicing by using a two-dim dataset
y = np.array(pd.factorize(df_iris['species'])[0])
h = .02  # step size in the mesh

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter

# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                    np.arange(y_min, y_max, h))

# title for the plots
titles = 'SVC'
svc = SVC(random_state=rn_state, kernel='linear')
svc = svc.fit(X, y)

Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title("svc")

plt.show()

# %% [markdown]
# Podemos ver la dificultad de separar estos datos a base de un hiperplano.
#
# Por lo que posiblemente, SVM no es el mejor modelo para resolver este problema

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# Logistic regression es posiblemente el único modelo que no se usa habitualmente para clasificación, sino como parte de un modelo de deep learning. Vereis su uso real más adelante.
#
# Pero esto no impide que scikit-learn tenga una implementación que podemos probar

# %%
logistic_regressor = linear_model.LogisticRegression(random_state=rn_state)
logistic_regressor = logistic_regressor.fit(X_train, y_train)
print('test accuracy: %.2f' % random_forest.score(X_test, y_test))
print('test precision: %.2f' % precision_score(y_test, y_predicted))
print('test recall: %.2f' % recall_score(y_test, y_predicted))
print('test f1: %.2f' % f1_score(y_test, y_predicted))
# Out:
# test accuracy: 0.79
# test precision: 0.81
# test recall: 0.71
# test f1: 0.76

# %% [markdown]
# Para entender qué está pasando vemos cómo el modelo funcionaría con una variable

# %%
from scipy.special import expit # sigmoid classifier forces a class, so we must use the sigmoid function
df_iris = pd.read_csv('IRIS.csv')
df_iris = df_iris[df_iris['species'].isin(['Iris-setosa', 'Iris-versicolor'])]
X = np.array(df_iris)[:, :1]  # we only take the first two features. We could
                    # avoid this ugly slicing by using a two-dim dataset
y_train = np.array(pd.factorize(df_iris['species'])[0])

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
h=0.01
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1

# title for the plots
titles = 'Logistic Regressor'
logistic_regressor = linear_model.LogisticRegression(random_state=rn_state)
logistic_regressor = logistic_regressor.fit(X, y_train)

Z = np.arange(x_min, x_max, h).reshape(-1, 1) * logistic_regressor.coef_ + logistic_regressor.intercept_
Z = expit(Z)

# Plot also the training points
plt.scatter(X, y_train, c='red')
plt.scatter(np.arange(x_min, x_max, h), Z, c='black')
plt.xticks(())
plt.yticks(())
plt.title("regresion logistica")

plt.show()

# %% [markdown]
# # Conclusiones

# %% [markdown]
# En esta sección, hemos estudiado:
#
# - Los dos tipos de aprendizaje supervisado: regresión y clasificación
#
# - Dentro de clasificación hemos visto modelos de tipo árbol, ensemble, SVM y regresión logística
#
# - Dentro de regresión hemos visto regresión lineal y LASSO.
#
# - Hemos visto cómo evaluar los modelos y cómo compararlos.
#
# De aquí en adelante, podremos resolver cualquier problema que correspondan a datos tabulados, ya sea para poder generar un modelo productivo como un análisis detallado de los datos.
